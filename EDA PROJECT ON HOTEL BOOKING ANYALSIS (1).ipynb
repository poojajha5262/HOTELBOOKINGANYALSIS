# %% [markdown]
# # **Project Name**    -  Hotel Booking Analysis
#
# ---

# %% [markdown]
# ##### **Project Type**    - EDA(Exploratory Data Analysis)
# ##### **Contribution**    - Individual

# %% [markdown]
# ### **GITHUBLINK**

# %% [markdown]
# https://github.com/poojajha5262/HOTELBOOKINGANYALSIS

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# In this project I got one csv file as an input. I first decided to take up this project solely due to My mutual interest in Hotel Booking.But when I downloaded the project dataset I was shocked to see so many data in csv file.first thing I had done in this project is that we have make a rough structure that what I need to do in this project and what will be generally the problems and their solution .Then we started working on it . First of all, I Downloaded the "hotel_bookings.csv" data file from the almabetter project dashboard to my computer, and then I uplaoded the data from my computer to the Google Drive in order to be able to perform data analysis and get insight from this data by fetching data with importing that data to colab and read it with readcsv. I began by importing all the necessary python packages and libraries. I imported Pandas with the alias pd, imported Numpy with the alias np, and imported matplotlib with the alias plt for the data visualization. I inserted the csv data into Padas dataframe and take some quick insight over the data.
# This dataset includes information on booking reservasion, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. The database distinguish between the booking information for 2 major hotels types a city hotel and a resort hotel
#
# The dataset includes a wide range of booking information with distinguish between city and a resort hotels. Here is a detailed list of the table topics with a short explnation of what each column means and the type of information it is storing:
# hotel: hotel type(H1 = Resort Hotel or H2 = City Hotel) is_canceled:
# Value indicating if the booking was canceled (1) or not (0) lead_time: Number of days that elapsed between the entering date of the booking into the PMS and the arrival date arrival_date_year:
# Year of arrival date arrival_date_month: Month of arrival date arrival_date_week_number: Week number of year for arrival date arrival_date_day_of_month: Day of arrival date stays_in_weekend_nights: Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel stays_in_week_nights: Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel adults: Number of adults children: Number of children babies: Number of babies country: Country of origin. Categories are represented in the ISO 3155–3:2013 format.
#
# After that I find out all null values and all the unexpected values and I replace this null with the other values like setting most repeated values in the place of null values or deleting the some values which doesn't make any sense.
#
# Then after preparing all the data I started to used plots to analyze this data in the way for better understanding . First I analyze which types of hotels are there and what are the ratio of it ,and it is observed that there are two types of hotels city hotels and resort hotel. 66% hotels are city hotels and 34% are resort hotels,then I observed between June and the end of August, attendance is at its peak, it is the high season.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Our problem statement is that we have to book a hotel/resort so then we need to check which one is best, depends on some of the aspect like what is the seasonality and what are the top performing months? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? and what are the top countries in terms of booking and revenue? what the most frequent guest type? This hotel booking dataset can help you explore those questions!

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The Hotel Booking Analysis project aims to achieve several key business objectives:
#
# 1. **Booking Patterns**: Identify peak booking seasons, lead times, and preferences between city hotels and resort hotels.
#
# 2. **Revenue Management**: Minimize booking cancellations and maximize occupancy rates through strategic insights.
#
# 3. **Guest Experience**: Personalize services and amenities based on guest demographics and preferences.
#
# 4. **Operational Efficiency**: Optimize resource allocation, such as parking spaces, by analyzing demand trends.
#
# 5. **Marketing Strategies**: Enhance targeting during peak seasons and refine pricing strategies to attract more guests.
#
# 6. **Risk Management**: Mitigate risks linked to seasonal fluctuations and economic conditions.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# ###Explore and analyze the data to discover results and statistics

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from seaborn.widgets import color_palette
import plotly
import plotly.express as px

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')

# %%
#file location is set
file_location = '/content/drive/MyDrive/EDA CAPSTONE PROJECT/Hotel Bookings.csv'

# %% [markdown]
# ### Dataset First View

# %%
#use pd.read_csv to read the data
Hotels_data=pd.read_csv(file_location)

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
Hotels_data.head()

# %%
Hotels_data.tail()
##it will shows the data of last five rows

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
Hotels_data.info()

# %%
Hotels_data.shape

# %% [markdown]
# #### Handling Duplicate Values

# %%
# Dataset Duplicate Value Count
Hotels_data.duplicated().sum()

# %%
#Remove duplicate values
Hotels_data.drop_duplicates(inplace=True)

# %%
Hotels_data.duplicated().sum()

# %% [markdown]
# Dataset having 31994 duplicate values and those are successfully removed

# %%
# Checking for new shape of dataset
Hotels_data.shape

# %% [markdown]
# first copy the data so that original data will remains unchange.

# %%
Hotels_data=Hotels_data.copy()

# %%
Hotels_data.describe()

# %% [markdown]
# ###Data prepartion and cleaning

# %% [markdown]
# 1. check is there any null value or missing values

# %%
# Check for missing/null values in Dataset
null_df=pd.DataFrame(Hotels_data.isna().sum()).rename(columns={0:'number_of_nulls_values'})
null_df

# %% [markdown]
# Null values for the features children, country, agent, and company are 4, 452, 12193, and 82137, respectively.

# %%
# Visualizing the missing values
plt.figure(figsize=(7,7))
null_df.plot(kind='bar')
plt.title('Graph of Number of null values with respect to its Variable')

# %%
# Percentage of null values
percentage_null_df=pd.DataFrame(round(Hotels_data.isna().sum()*100/len(Hotels_data),4)).rename(columns={0:'percentage_null_values'})
percentage_null_df

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Children, country, agent, and company variables have null values of 0.0046%, 0.5172%, 13.9514%, and 93.9826%, respectively. Variable companies having more than 50% null values

# %%
#checking category of features whoes having null values
Hotels_data.country.value_counts()

# %%
Hotels_data.children.value_counts()

# %%
Hotels_data.company.value_counts()

# %%
#replace the null values 0.0 float
Hotels_data['company'] = Hotels_data['company'].fillna(0.0)
Hotels_data['company'].head(23)

# %%
Hotels_data.shape

# %%
# Besic statistical description fo Dataset
Hotels_data.describe()

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %% [markdown]
# Categorical veriables

# %%
# Dataset Columns
# Obtaining categorical veriables
categorical_veriables=[i for i in Hotels_data.columns if Hotels_data[i].dtypes=='O']
print(f'Dataset having {len(categorical_veriables)} categorical variables')
print('--'*39)
print(categorical_veriables)

# %% [markdown]
# Numerical variables

# %%
numerical_variables=[i for i in Hotels_data.columns if Hotels_data[i].dtypes!='O']
print(f'There are {len(numerical_variables)} numerical variables.')
print('--'*39)
print(numerical_variables)

# %%
# Obtaining Descrete varibles from Numerical varibles
# Variables having less than 150 categories are consider as descrete variable
descrete_variavles=[]
for i in numerical_variables:
  if len(Hotels_data[i].value_counts())<=150:
    descrete_variavles.append(i)
    print(i,':',Hotels_data[i].unique())
    print('__'*39)
  else:
      pass

print(f'Dataset having {len(descrete_variavles)} descrete variables')

# %%
# Obtaining contineous variables from numerical variables
contineous_variables=[i for i in numerical_variables if i not in descrete_variavles]
print(f'Dataset having {len(contineous_variables)} contineous variables')
print('--'*39)
print(contineous_variables)

# %%
# Dataset Describe
Hotels_data.describe()

# %%
# Checking for outliers for contineous variables

from scipy.stats import norm
for i in contineous_variables:
  plt.figure(figsize=(15,6))
  plt.subplot(1,2,1)
  ax=sns.boxplot(data=Hotels_data[i])
  ax.set_title(f'{i}')
  ax.set_ylabel(i)

  plt.subplot(1,2,2)
  ax=sns.distplot(Hotels_data[i], fit=norm)
  ax.set_title(f'skewness of {i} : {Hotels_data[i].skew()}')
  ax.set_xlabel(i)
  print('__'*39)
  plt.show()

# %% [markdown]
# Outliers were found in the variables lead_time and adr, but not in the variable agent.

# %%
# Using Inter Quartile range in skew symmetric curve for removing outliers

# Outlier columns
outliers_columns=['lead_time','adr']

# Copy dataset as new dataset
new_df=Hotels_data.copy()

# Capping dataset
for i in outliers_columns:
    #Findng IQR
    Q1=new_df[i].quantile(0.25)
    Q3=new_df[i].quantile(0.75)
    IQR=Q3-Q1

    # Defining lower and upper limit
    lower_limit =new_df[i].quantile(0.25)-1.5*IQR
    upper_limit =new_df[i].quantile(0.75)+1.5*IQR

    # Applying lower and upper limit to each variables
    new_df.loc[(new_df[i] > upper_limit),i] = upper_limit
    new_df.loc[(new_df[i] < lower_limit),i] = lower_limit

# %%
# Checking for outliers for contineous variables
from scipy.stats import norm
for i in outliers_columns:
  plt.figure(figsize=(15,6))
  plt.subplot(1,2,1)
  ax=sns.boxplot(data=new_df[i])
  ax.set_title(f'{i}')
  ax.set_ylabel(i)

  plt.subplot(1,2,2)
  ax=sns.distplot(new_df[i], fit=norm)
  ax.set_title(f'skewness of {i} : {new_df[i].skew()}')
  ax.set_xlabel(i)
  print('__'*50)
  plt.show()

# %% [markdown]
# Ouliers in the lead_time and adr variables were removed.

# %%
# Describe outlier free new_df
new_df.describe()

# %% [markdown]
# Variables Information

# %% [markdown]
# 1. hotel:- Name of hotel ( City or Resort)
# 2. is_canceled:- Whether the booking is canceled or
# 3. not (0 for no canceled and 1 for canceld)
# 4. lead_time:- time (in days) between booking
#   transaction and actual arrival.
# 5. arrival_date_year:- Year of arrival
# 6. arrival_date_month:- month of arrival
# 7. arrival_date_week_number:- week number of
#    arrival date.
# 8. arrival_date_day_of_month:- Day of month of      arrival date
# 9. stays_in_weekend_nights:- No. of weekend nights spent in a hotel
# 10. stays_in_week_nights:- No. of weeknights spent in a hotel
# 11. adults:- No. of adults in single booking record.
# 12. children:- No. of children in single booking record.
# 13. babies:- No. of babies in single booking record.
# 14. meal:- Type of meal chosen
# 15. country:- Country of origin of customers (as mentioned by them)
# 16. market_segment:- What segment via booking was made and for what purpose.
# 17. distribution_channel:- Via which medium booking was made.
# 18. is_repeated_guest:- Whether the customer has made any booking before(0 for No and 1 for Yes)
# 19. previous_cancellations:- No. of previous canceled bookings.
# 20. previous_bookings_not_canceled:- No. of previous non-canceled bookings.
# 21. reserved_room_type:- Room type reserved by a customer.
# 22. assigned_room_type:- Room type assigned to the customer.
# 23. booking_changes:- No. of booking changes done by customers
# 24. deposit_type:- Type of deposit at the time of making a booking (No deposit/ Refundable/ No refund)
# 25. agent:- Id of agent for booking
# 26. company:- Id of the company making a booking
# 27. days_in_waiting_list:- No. of days on waiting list.
# 28. customer_type:- Type of customer(Transient, Group, etc.)
# 29. adr:- Average Daily Rate.
# 30. required_car_parking_spaces:- No. of car parking asked in booking

# %% [markdown]
# ## 3. Data Wrangling

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write yo# Dataset
new_df

# %%
#checking unique values in each variable
for i in new_df.columns:
    print(f'{i}:{new_df[i].unique()}')
    print('__'*50)

# %%
# Checking info of newly formed dataset after removed outliers
new_df.info()

# %%
# Assuming new_df is your DataFrame
# Replace NaN with 0 in 'children' and 'agent' columns
new_df['children'].fillna(0, inplace=True)
new_df['agent'].fillna(0, inplace=True)

# Convert 'children' and 'agent' columns to int64
new_df[['children', 'agent']] = new_df[['children', 'agent']].astype('int64')

# Change datatype of variable reservation_status_date to correct format from object to datetime64
new_df['reservation_status_date']=pd.to_datetime(new_df['reservation_status_date'], format='%Y-%m-%d')

# %%
# Checking datatype
new_df[['children','agent','reservation_status_date']].info()

# %%
# Adding night stays on week night and weekend night in one variable to 'total_stays'
new_df['total_stays']=new_df['stays_in_weekend_nights']+ new_df['stays_in_week_nights']

# Converting "adults," "children," and "babies" to total_people by adding it
new_df['total_people']= new_df['adults']+ Hotels_data['children']+ new_df['babies']

# Creating 'total_childrens' variable by adding 'chldrens' and 'babies' variables
new_df['total_childrens']= Hotels_data['children']+ new_df['babies']

# Creating 'reserved_room_assigned' variable which describe same room assigned or not
new_df['reserved_room_assigned']=np.where(new_df['reserved_room_type']==new_df['assigned_room_type'], 'yes', 'no')

# Creating 'guest_category' from variable 'total_people'
new_df['guest_category']=np.where(new_df['total_people']==1, 'single',
                                 np.where(new_df['total_people']==2, 'couple', 'family'))

# Creating 'lead_time_category' from 'lead_time' variale to display category
new_df['lead_time_category']=np.where(new_df['lead_time']<=15, 'low',
                                 np.where((new_df['lead_time']>15) & (new_df['lead_time']<90), 'medium', 'high'))

#checking dataset
new_df.head()

# %%
new_df.shape

# %%
# Remove observations having value 0 in total_people variable
new_df.drop(new_df[new_df['total_people']==0].index, inplace=True)

# %%
new_df.shape

# %% [markdown]
# Because observations of the variable total_people cannot be zero, observations with 0 values are removed, reducing the number of observations to 87230 from 87396.

# %%
# Checking info of new dataset
new_df.info()

# %%
# Replace NaN with 0 in 'total_people' and 'total_childrens' columns
new_df['total_people'].fillna(0, inplace=True)
new_df['total_childrens'].fillna(0, inplace=True)

# Convert 'total_people' and 'total_childrens' columns to int64
new_df['total_people'] = new_df['total_people'].astype('int64')
new_df['total_childrens'] = new_df['total_childrens'].astype('int64')

# %%
#Checking datatype of total_column
new_df[['total_people','total_childrens']].info()

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# *   The variables "children," "agent," "reservation_status_date," "total_people," and "total_children" do not have the correct datatype format. So they are transformed from float64 datatypes to int64. The variable "reservation_status_date" was transformed from object datatype to datetime64.
# *   For more convenience in the dataset, "total_stays" and "total_people" variables are created. By adding the variables "stays_in_weekend_nights" and "stays_in_weeknights," the variable "total_stays" is created. The variables "adults," "children," and "babies" are combined, the variable "total_people" is created.
# *   The variable "reserved_room_assigned" is made up of the variables "reserved_room_type" and "assigned_room_type," which describe whether or not a reserved room for a customer has been assigned. From variables "children" and "babies," a new "total_children" variable is created by adding both of them.
# *   The variable "total_people" was used to create "guest_category," which describes bookings made for individuals, couples, or families. The variable 'lead_time_category' was created from the variable 'lead_time' to display lead time as low, medium, and high.
# *   Variable "total_people" cannot be 0, so observations in total_people having 0 values are dropped.

# %% [markdown]
# ## 4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables

# %% [markdown]
# Univariate Analysis

# %%
# Obtaing target variable
excluded_variables=[var for var in new_df.columns if len(new_df[var].value_counts()) > 15]
target_variables=[var for var in new_df.columns if var not in excluded_variables]

# Defining r to autofit the number and size of plots
r = int(len(target_variables)/3 +1)

# %%
# Defining a function to Notate the percent count of each value on the bars
def annot_percent(axes):
    '''Takes axes as input and labels the percent count of each bar in a countplot'''
    for p in plot.patches:
        total = sum(p.get_height() for p in plot.patches)/100
        percent = round((p.get_height()/total),2)
        x = p.get_x() + p.get_width()/2
        y = p.get_height()
        plot.annotate(f'{percent}%', (x, y), ha='center', va='bottom')

# %%
# Plotting the countplots for each variable in target_variables
plt.figure(figsize=(18,r*3))
for n,var in enumerate(target_variables):
    plot = plt.subplot(r,3,n+1)
    sns.countplot(x=new_df[var]).margins(y=0.15)
    plt.title(f'{var.title()}',weight='bold')
    plt.tight_layout()
    annot_percent(plot)

# %% [markdown]
# Bivariate Analysis

# %% [markdown]
# #### Chart - 1
# Question: Is not having a reserved room assigned a reason for booking cancellations?

# %%
# Plotting count plot for is_canceled in terms of reserved_room_assigned
plt.figure(figsize=(5,5))
plot=plt.subplot(111)
ax=sns.countplot(x=new_df['is_canceled'], hue=new_df['reserved_room_assigned'])
ax.set_title('is_canceled v/s reserved_room_assigned')
annot_percent(plot)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart is selected because it effectively visualizes categorical data relationships, facilitates comparison across multiple categories, and provides clear insights into cancellation patterns based on room assignment status. These characteristics make it a suitable choice for analyzing the interplay between is_canceled and reserved_room_assigned in your dataset.Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The inability to assign a reserved room to a customer is not grounds for cancellation. Less than 1% of people who cancelled their booking when the reserved room was not assigned.Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# 1. Optimized Room Assignment: Identifying room assignment practices that reduce cancellations enhances guest satisfaction and retention.
#
# 2. Revenue Management: Lower cancellation rates improve revenue predictability and utilization of resources.
#
# 3. Guest Experience: Tailored room assignments based on insights lead to enhanced guest satisfaction and potential for positive reviews.
#
#
# Potential Negative Impact:
#
# 1. Overgeneralization: Applying insights broadly without considering individual guest preferences may lead to dissatisfaction.
#
# 2. Rigidity in Policies: Relying solely on data-driven strategies may overlook seasonal variations or special guest needs.
#
# Balancing data-driven insights with guest feedback ensures operational efficiency enhances rather than detracts from guest satisfaction and loyalty.

# %% [markdown]
# #### Chart - 2
# Question  : Is the high lead_time a reason for booking cancellations?

# %%
# Plotting count plot for lead_time_category in terms of is_canceled
plt.figure(figsize=(5,5))
plot=plt.subplot(111)
ax=sns.countplot(x=new_df['lead_time_category'], hue=new_df['is_canceled'])
ax.set_title('lead_time_category v/s is_canceled')
annot_percent(plot)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart sns.countplot() is chosen for its ability to effectively compare categorical variables lead_time_category and is_canceled, visualize distribution and patterns, generate insights into cancellation behaviors based on lead times, and provide clear and interpretable results with the aid of percentage annotations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Less lead time means fewer cancellations. Customers who book hotels more than 15 days in advance are more likely to cancel their booking. Booking cancellations are not caused by a longer Lead time

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Positive Impact Justification:
#
# 1. **Identifying Cancellation Patterns**: When we look at how often bookings get canceled in different time categories, we can figure out when cancellations are most likely to happen. This helps us plan ahead with things like targeted ads or special deals to try to stop cancellations.
#
# 2. **Strategic Planning**: When we know which time categories have more cancellations, we can change our plans. For example, we could offer more choices to cancel or rewards for booking early. This helps us lower risks in the categories where cancellations happen a lot.
#
# ### Potential Negative Impacts Justification:
#
# 1. **Overgeneralization**: The graph might show patterns, but thinking all bookings in a category will cancel is not true. It's important to look at more data and think about other things that can change it, like seasons or how much it costs. This helps us make sure plans we make are good.
#
# 2. **Misinterpretation of Causation**: The graph shows how things are related, not how one makes another happen. For example, if bookings cancel more when there's not a lot of time, it might not be because of that. It could be because of other things, like how much it costs or what other places have.

# %% [markdown]
# #### Chart - 3
# Question: How many people are reservations made for?

# %%
# Plotting count plot for hotel
plt.figure(figsize=(5,5))
plot=plt.subplot(111)
ax=sns.countplot(x=new_df['hotel'], hue=new_df['guest_category'])
ax.set_title('hotel v/s guest_category')
annot_percent(plot)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# the countplot with hotel on the x-axis and guest_category as the hue is chosen because it effectively visualizes categorical data relationships, aids in understanding customer behavior and preferences across different hotels, and provides clear insights into the distribution of guest categories within each hotel type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most customers book hotels for two people (couples). Customers prefer city hotels over resorts for family bookings. A city hotel is preferred when booking for a single person.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# 1. Targeted Marketing and Services:
#    - Impact: With this knowledge, hotels can tailor their marketing efforts and services. They can focus on advertising to the specific types of guests who are most likely to stay at their hotel. This targeted approach can lead to more bookings and higher occupancy rates.
#
# 2. Enhanced Customer Experience:
#    - Impact: Hotels can offer customized amenities and services that match the preferences of their main guest categories. This can improve guest satisfaction, encourage repeat bookings, and generate positive word-of-mouth recommendations.
#
# 3. Optimized Revenue Management:
#    - Impact: Hotels can adjust their pricing based on demand from different guest segments. For instance, they can use dynamic pricing to maximize revenue during busy times or adjust rates for less popular guest categories to attract more bookings.
#
# Potential Negative Impact:
#
# 1. Misguided Resource Allocation:
#    - Risk: Misinterpreting the data might lead hotels to invest resources inefficiently.
#    - Impact: For example, assuming one guest category dominates a hotel type and spending heavily on amenities for that segment without confirming actual demand could waste resources and reduce profitability if guest preferences or behaviors change unexpectedly.
#
# 2. Customer Alienation:
#    - Risk: Focusing too much on one guest category could alienate other potential customer segments.
#    - Impact: Hotels might unintentionally ignore or neglect profitable segments by overly targeting a specific type of guest. This could result in missed opportunities to attract a diverse customer base and grow long-term revenue.
#
# - Negative Growth Justification: Potential pitfalls include misunderstanding guest preferences, which might lead to inefficient resource allocation and overlooking opportunities with other guest segments. Also, overly focusing on a single guest category could limit a hotel’s appeal and hinder growth potential.

# %% [markdown]
# #### Chart - 4
# Question: Which hotel type has the most advanced reservations?

# %%
# Plotting violin plot for hotel against lead_time
plt.figure(figsize=(5,5))
sns.violinplot(x=new_df['hotel'], y=new_df['lead_time'])
ax.set_title('is_canceled v/s lead_time')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# the violin plot is selected as it offers a robust method to visualize and compare the distribution of lead times across various hotel types, facilitating insights into booking patterns and operational considerations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In comparison to city hotels, guests book resort hotels a little bit in advance.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# 1. Operational Planning:
#    - Impact: Hotels can optimize their operations by adjusting staffing schedules and inventory management to align with peak booking periods identified from the plot. This can lead to improved efficiency and cost savings.
#
# 2. Revenue Management:
#    - Impact: Optimized pricing strategies can lead to increased revenue per available room (RevPAR) and overall profitability.
#
# 3. Customer Experience:
#    - Impact: Positive guest experiences can foster loyalty, generate repeat bookings, and lead to positive reviews and referrals.
#
# Potential Negative Impact:
#
# 1. Overemphasis on Short-Term Bookings:
#    - Impact: Over-reliance on short-term bookings can lead to inconsistent revenue streams and hinder long-term growth and stability.
#
# 2. Misinterpretation of Causation:
#    - Impact: This misinterpretation might result in ineffective marketing campaigns or pricing adjustments that do not resonate with actual guest preferences or market conditions.
#
# Justification:
# - Negative Growth Justification: Potential pitfalls include focusing too heavily on short-term strategies at the expense of long-term planning, and making assumptions about causation without sufficient validation. These could lead to missed opportunities for sustainable growth and profitability.

# %% [markdown]
# #### Chart - 5
# Question : Which distribution channels have the most cancellations of bookings?

# %%
# Plotting a count plot for distribution channels in terms of the number of booking cancellations
plt.figure(figsize=(5,5))
plot=plt.subplot(111)
ax=sns.countplot(x=new_df['distribution_channel'], hue=new_df['is_canceled'])
ax.set_title('% of booking cancellations per distribution channel')
annot_percent(plot)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The countplot with distribution_channel against is_canceled is selected because it effectively visualizes cancellation trends across different booking channels, facilitating informed decision-making and strategic planning aimed at reducing cancellations and enhancing operational efficiency.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The majority of canceled bookings were made through the TA/TO distribution channel. Bookings made through the Direct, Corporate, and GDS distribution channels are extremely unlikely to be canceled.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# 1. Targeted Improvement Strategies:
#    - Impact: Hotels can focus on improving booking processes, customer service, or incentives for channels with high cancellation rates. This targeted approach can potentially reduce cancellations, increase booking conversions, and improve revenue stability.
# 3. Operational Efficiency:
#    -Impact: Streamlining operations in response to cancellation trends can lead to cost savings and improved overall efficiency, ensuring resources are allocated effectively.
#
# Potential Negative Impact:
#
# 1. Overemphasis on Channel-Specific Strategies:
#    -Impact: This could lead to neglecting other important aspects of customer acquisition and retention strategies. Hotels might miss opportunities to attract diverse customer segments or fail to adapt to changing market conditions.
#
# 2. Customer Alienation:
#    -Impact: If strategies designed to reduce cancellations are perceived as intrusive or inflexible, they may alienate customers and result in decreased satisfaction or loyalty.
#
# Negative Growth Justification: Potential pitfalls include tunnel vision on channel-specific metrics at the expense of holistic customer relationship management and overlooking customer-centric approaches. Misinterpretation of cancellation trends could lead to misguided strategies that do not resonate with customer expectations or market dynamics.

# %% [markdown]
# #### Chart - 6
# Question : Which market segment is most used for booking hotels, and which market segment bookings are most canceled?

# %%
# Plotting count plot for market segment
plt.figure(figsize=(10,5))
ax=sns.countplot(x=new_df['market_segment'], hue=new_df['is_canceled'])
ax.set_title('booking cancellations per market_segment')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# the countplot with market_segment against is_canceled is chosen because it efficiently visualizes cancellation patterns across different customer segments, providing valuable insights that can inform strategic initiatives to enhance customer retention and operational efficiency.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The majority of hotel reservations are made online, as are the majority of cancellations of reservations made by customers who made their reservations online.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# 1. Targeted Marketing Strategies:
#    - Impact: Hotels can tailor their marketing messages and promotional strategies to address the specific needs and preferences of each market segment. This targeted approach can increase booking conversions and improve overall revenue.
#
# 2. Enhanced Customer Retention:
#    - Impact: By addressing the reasons behind cancellations within each segment (e.g., offering flexible cancellation policies for leisure travelers or exclusive perks for corporate clients), hotels can enhance customer satisfaction and loyalty, leading to repeat bookings and positive word-of-mouth.
#
# 3. Operational Efficiency:
#    - Impact: Hotels can optimize resource allocation, staffing, and inventory management based on booking stability within different market segments. This can reduce costs and improve overall operational performance.
#
# Potential Negative Impact:
#
# 1. Overemphasis on Cancellation Metrics:
#    -Impact: This may lead to neglecting high-value segments that have higher cancellation rates but contribute significantly to revenue and long-term business growth. Hotels may miss opportunities to capitalize on the potential value these segments offer.
#
# 2. Customer Segmentation Complexity:
#    -Impact: Hotels might overlook nuances within segments or fail to adapt strategies effectively. For instance, assuming all bookings from a specific segment are equally likely to cancel without considering factors like booking purpose or loyalty status could lead to ineffective strategies.
#
# - Negative Growth Justification: Potential pitfalls include focusing solely on cancellation metrics at the expense of broader customer relationship management and misinterpreting segment behaviors. This could lead to missed opportunities for revenue growth and customer retention, impacting long-term profitability and market competitiveness.

# %% [markdown]
# #### Chart - 7
# Question: Which month is the busiest for hotels?

# %%
# Bar plot for arrival month of customer against waiting days for bookings
plt.figure(figsize=(10,7))
plot=plt.subplot(111)
ax=sns.barplot(x=new_df['arrival_date_month'], y=new_df['days_in_waiting_list'], hue=new_df['hotel'])
ax.set_title('bar plot of arrival_date_month vs. days_in_waiting_list in terms of hotel types')
annot_percent(plot)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar plot with arrival_date_month against days_in_waiting_list, segmented by hotel, is chosen because it allows for a clear and comparative analysis of waiting times across different months and hotel types. This visualization helps in understanding booking dynamics and operational challenges related to waiting list management throughout the year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Customers prefer city hotels over resort hotels for the New Year. The city hotel is busiest in October and September , which means that this month has the most bookings. In the fourth quarter of the year, in December, resorts are busier than city hotels. Resort hotels are significantly less busy in the third quarter of the year than they are throughout the year. In July there is no longer waiting period for bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# 1. Optimized Resource Management:
#    - Impact: By adjusting staffing and room availability based on busy times, hotels can work more smoothly. This can improve how well the hotel runs and make guests happier.
#
# 2. Better Customer Experience:
#    - Impact: Hotels can manage what guests expect better, like quicker check-ins or special attention during busy times. This can make guests happier and more likely to come back.
#
# 3. Smart Business Planning:
#    - Impact: By adjusting prices and offers when things are slower, hotels can bring in more money. This way of planning can mean more profit and make the hotel stand out.
#
# Potential Negative Impact:
#
# 1. Risk of Uneven Service:
#    - Impact: Guests who wait longer might feel the service isn't good enough. This could lead to bad reviews and fewer guests coming back, hurting the hotel's reputation.
#
# 2. Challenges with Operations:
#    -Impact: Trying too hard to cut waiting times (like having too many staff in busy times) could mean higher costs. This might cancel out any extra money made from happier guests.
#
# Negative Impact Reasoning: There's a risk that different waiting times could mean uneven service, and focusing only on cutting waiting times might cost too much or not work well. Hotels need to think about both how things are now and how much things cost to make smart decisions that help guests and keep the hotel making money.

# %% [markdown]
# [link text](https://)#### Chart - 8
# Question : Which customer type generates more revenue in terms of hotel types and customer types?

# %%
# Plotting bar plot for diffrent customers type against ADR
plt.figure(figsize=(5,5))
plot=plt.subplot(1,1,1)
ax=sns.barplot(x=new_df['customer_type'], y=new_df['adr'], hue=new_df['hotel'])
ax.set_title('bar plot of customer_type vs. adr in terms of hotel types')
annot_percent(plot)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# City hotels generate more revenue (54.86%) than resort hotels (45.14%). Transient customers who book rooms for a short period of time generate more revenue than other types of customers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# 1. Optimized Pricing Strategies:
#    - Impact: Hotels can adjust pricing to better match the willingness of each customer segment to pay, potentially increasing revenue by attracting more bookings from higher-spending segments.
#
# 2. Targeted Marketing Efforts:
#    - Impact: Hotels can tailor promotions and advertising to appeal more effectively to each customer segment, leading to increased bookings and higher occupancy rates.
#
# 3. Revenue Management:
#    - Impact: Hotels can allocate resources and adjust room rates strategically to maximize profitability, especially during peak demand periods.
#
# Potential Negative Impact:
#
# 1. Risk of Customer Alienation:
#    - Impact: This could lead to negative reviews, decreased customer satisfaction, and reduced loyalty, ultimately impacting occupancy rates and revenue.
#
# 2. Competitive Disadvantage:
#    - Impact: Hotels may fail to attract desired customer segments or lose market share to competitors who better understand and cater to customer pricing expectations.
#
# - Negative Growth Justification: There's a risk of customer dissatisfaction and reduced loyalty if pricing strategies are perceived as unfair or if competitors offer more attractive rates. Additionally, overreliance on segmentation could lead to missed opportunities to attract a broader customer base.

# %% [markdown]
# #### Chart - 9
#
# Question 9 : Does a longer waiting period cause the cancellation of bookings?

# %%
#Selecting bookings with non zero waiting time
waiting_time=new_df[new_df['days_in_waiting_list']!=0]

#ploting graph

plt.figure(figsize=(5,5))
ax=sns.kdeplot(x=waiting_time['days_in_waiting_list'], hue=waiting_time['is_canceled'])
ax.set_title('days_in_waiting_list')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# the KDE plot chosen for days_in_waiting_list among bookings with non-zero waiting times is selected because it effectively visualizes the distribution of waiting times and allows for insights into cancellation patterns, thereby supporting operational improvements and customer retention strategies in hospitality management.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The majority of canceled bookings have a waiting period of less than 150 days, but those that are not canceled bookings by customers have a waiting period of less than 150 days, which has a higher density than the canceled bookings. So a longer waiting period is not a reason for booking cancellation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# 1. Optimized Operational Efficiency:
#    - Impact: By managing waiting times more efficiently, hotels can reduce guest dissatisfaction and improve operational flow, leading to smoother operations and enhanced customer satisfaction.
#
# 2. Enhanced Customer Experience:
#    - Impact: Hotels can implement strategies such as better communication with guests or offering alternatives during longer waiting periods. This can enhance guest satisfaction and loyalty, leading to positive reviews and repeat bookings.
#
# 3. Improved Revenue Management:
#    - Impact: Hotels can adjust pricing or promotional offers based on anticipated demand patterns associated with waiting times, potentially increasing revenue during peak periods.
#
# Potential Negative Impact:
#
# 1. Risk of High Cancellation Rates:
#    - Impact: High cancellation rates can lead to revenue loss and affect occupancy rates, impacting overall profitability and market competitiveness.
#
# 2. Operational Challenges:
#    - Impact: This may result in increased operational costs and decreased efficiency, potentially offsetting any revenue gains from improved customer satisfaction.
#
# Negative Growth Justification: There's a risk that insights revealing longer waiting times associated with cancellations could indicate underlying service issues or dissatisfaction among guests. Failing to address these concerns could lead to higher cancellation rates, reduced revenue, and negative guest perceptions.

# %% [markdown]
# #### Chart - 10
# Question : What is the most common number of special requests made by customers, and what kind of customer are they?

# %%
# Plotting count plot for total_of_special_requests in terms of different guest type
plt.figure(figsize=(10,5))
plot=plt.subplot(111)
ax=sns.countplot(x=new_df['total_of_special_requests'], hue=new_df['guest_category'])
ax.set_title('total_of_special_requests by % of customers')
annot_percent(plot)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The count plot for total_of_special_requests in terms of different guest types is selected because it efficiently visualizes categorical data, supports comparative analysis across guest categories, and provides actionable insights relevant to optimizing service delivery and guest satisfaction strategies in hospitality management.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Approximately half of all customers do not make special requests. Customers frequently make one special request. Couples make the majority of special requests. Bookings made for single people are not more requested for special requests than those made for couples, followed by family and business events.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# 1. Tailored Service Offerings:
#    - Impact: By catering to specific preferences identified through the count plot (e.g., offering more amenities or customization options for guests who frequently make special requests), hotels can enhance guest satisfaction and loyalty, leading to positive reviews and repeat bookings.
#
# 2. Operational Efficiency:
#    - Impact: Hotels can allocate resources more effectively, ensuring that they meet guest expectations without unnecessary costs. This efficiency can lead to improved profitability and operational performance.
#
# 3. Marketing Strategies:
#    - Impact: Hotels can attract more guests by highlighting their ability to accommodate various special requests effectively. This can differentiate them from competitors and increase booking conversions.
#
# Potential Negative Impact:
#
# 1. Overgeneralization of Insights:
#    - Impact: Overgeneralization can lead to misalignment between service offerings and guest expectations, resulting in dissatisfaction and potential negative reviews. Hotels may miss opportunities to customize services based on individual guest needs.
#
# 2. Operational Challenges:
#    - Impact: Hotels may face difficulties in maintaining consistency and quality across all guest interactions, especially during peak periods. This could undermine service standards and lead to negative guest experiences.
#
# Negative Growth Justification: Risks such as overgeneralization of guest preferences and operational challenges highlight the importance of balancing customization with operational feasibility. Hotels must validate insights with broader guest feedback and optimize resource allocation to mitigate potential negative impacts on service quality and operational efficiency.

# %% [markdown]
# ###Multivariate Analysis

# %% [markdown]
# #### Chart - 11 - Correlation Heatmap

# %%
# Select numeric columns for correlation analysis
numeric_columns = new_df.select_dtypes(include=['float64', 'int64']).columns

# Plot correlation heatmap for numeric columns
plt.figure(figsize=(15, 8))
sns.heatmap(new_df[numeric_columns].corr(), vmin=-1, cmap='coolwarm', annot=True)
plt.title('Correlation Heatmap of Numeric Variables')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# the correlation heatmap chosen for new_df allows for a systematic exploration of relationships among numeric variables, facilitating data-driven decision-making and insights that can drive positive outcomes across various aspects of business and analytical tasks.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - In the heatmap, we see some high correlation between a few variables because we created new variables total_stays, total_people, and total_children from existing variables and did not drop old variables.
# - The variables lead_time and is_canceled have weak relationships. The most likely reason for cancellation is a longer lead time.

# %% [markdown]
# #### Chart - 12 - Pair Plot

# %%
# Creating new dataset
new_df2=new_df[['hotel','is_canceled','lead_time','arrival_date_year','arrival_date_month','meal','market_segment','distribution_channel','reserved_room_type',
       'assigned_room_type','deposit_type','days_in_waiting_list', 'customer_type', 'adr','total_stays',
       'total_people', 'total_childrens', 'reserved_room_assigned',
       'guest_category', 'lead_time_category']]

# Plotting pair plot for dataset
plt.figure(figsize=(10,8))
ax=sns.pairplot(new_df2)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pair plot selected for new_df2 is well-suited for exploring relationships and patterns within the dataset, enabling deeper insights that can guide strategic decisions and further analytical exploration in various domains such as hospitality management and customer behavior analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can conclude from the relationship between lead_time and is_canceled that a longer lead time does not result in cancellations.
# We can conclude from the lead_time and arrival_date_year graphs that people were consistently interested in booking rooms in advance in 2015, 2016, and 2017.
# According to the graph of arrival_date_year and days_in_waiting_list, 2016 had the longest waiting period for room bookings.
# We can conclude from the graph of ADR and days_in_waiting_list that a short minimum waiting period for bookings results in a high ADR.
# From the graph of "is_canceled" and "days_in_waiting_list," we conclude that waiting for bookings is not a reason for booking cancellation.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# 1. Promoting Resort Hotel Bookings:
#    - Since the city hotel has more bookings, offer attractive packages and promotions specifically for the resort hotel. Highlight unique amenities and experiences to draw more bookings towards the resort.
#
# 2. Promoting Food Variety:
#    - BB is the most popular food choice, so maintain its quality. Offer discounts on other food types to encourage guests to try different options. This approach helps in managing kitchen load and offering a variety of dining choices.
#
# 4. Increasing Repeat Bookings:
#    - Since only 3.86% of customers return, incentivize repeat bookings with targeted promotions. Understand customer preferences and interests from past bookings to create appealing offers that encourage guests to book again.
#
# 5. Room Type Management:
#    - Rooms A and D are popular, so maintain their quality. Promote less popular rooms (E, F, G) with discounts to increase their demand. Consider phasing out less preferred room types (B, C, H, L) to reduce costs.
#
# 6. Advance Deposits for Bookings:
#    - Encourage advance deposits to secure bookings. This not only accelerates revenue recognition but also reduces cancellation risks. Implement clear policies and incentives to encourage guests to make deposits.
#
# 7. Parking Space Management:
#    - Offer bookings primarily for 1 and 2 parking spaces, as 3 and 8 spaces are rarely requested. This saves costs and streamlines operations related to parking availability.
#
# 8. Room Reservation Accuracy:
#    - Ensure guests receive the rooms they booked. Improve booking accuracy and communication to prevent guest dissatisfaction and ensure a positive experience upon arrival.
#
# 9. Reducing Booking Cancellations:
#    - With nearly 25% cancellations, implement a robust cancellation policy. Offer discounts on confirmed bookings and send timely reminders to reduce cancellations and optimize occupancy rates.
#
# 10. Promoting Group Bookings:
#     - Encourage family and group bookings with special discounted offers. Maximize revenue by promoting packages that cater to larger groups, emphasizing value and convenience for group stays.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1. Top Booking Country: PRT has the highest number of bookings.
# 3. Preference for City Hotels: City hotels are favored over resort hotels by 61.07%.
# 4. Cancellation Rate: One out of every four reservations is canceled.
# 5. Popular Food Choice: BB is the most popular food choice.
# 6. Booking Platform: The majority of bookings are made online (internet).
# 7. Preferred Distribution Channel: TA/TO is the leading distribution channel for bookings.
# 8. New Guests vs. Returning Guests: Nearly all guests (96.14%) are new customers; only 3.86% are returning guests.
# 9. Preferred Room Type: Room A is the most requested by customers.
# 10. Pre-Deposit Preference: Customers prefer bookings without pre-deposits.
# 11. Length of Stay: About 80% of customers prefer short visits.
# 12. Parking Preference: Only 10% of guests require parking space.
# 13. Visitor Composition: Most visitors are couples.
# 14. Room Assignment Policy: Failure to assign a reserved room does not lead to cancellation.
# 15. Impact of Lead Time on Cancellations: Longer lead times do not significantly affect cancellation rates.
# 16. Hotel Occupancy: City hotels are busier than resorts.
# 17. Busiest Months: October and September are the busiest months; July has shorter wait times for reservations.
# 18. Impact on Average Daily Rate (ADR): Not assigning a reserved room does not impact the ADR conclusion.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
